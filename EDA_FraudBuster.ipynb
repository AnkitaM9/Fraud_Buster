# %% [markdown]
# 1. Importing the Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Upload Dataset

# %%
data=pd.read_csv('dataset/creditcard_2023.csv')

# %% [markdown]
# 3. Exploring DataFrame

# %%
data.shape
data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %% [markdown]
# 3.1  Checking for missing values

# %%
missing_data=data.isnull().any()
print(missing_data)
# Out:
# id        False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %% [markdown]
# 4.  Visualization Type-Histogram
# * Distribution of dataset

# %%
data.hist(bins=50, figsize=(20, 15) )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 5. Sperated dataset into Not Fraud and Fraud

# %%
fraud=data[data['Class']==1]
not_fraud=data[data['Class']==0]
print(f"Not Fraud [0]: {not_fraud.shape}, Fraud [1]: {fraud.shape}")
# Out:
# Not Fraud [0]: (284315, 31), Fraud [1]: (284315, 31)

# %% [markdown]
# 6. Class Distribution

# %%
category_counts=data['Class'].value_counts()
print(category_counts)
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.catplot(x='Class', kind='count', data=data, hue='Class' , palette='Set2')
plt.title('Distribution of Class')
plt.xticks([0, 1], [' Not Fraud', 'Fraud', ])
plt.ylabel('Count') 
plt.show()

# %% [markdown]
# 6.1 Analyzing the amount of money involved in different transaction classes.

# %%
not_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean      12026.313506
# std        6929.500715
# min          50.120000
# 25%        6034.540000
# 50%       11996.900000
# 75%       18040.265000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count    284315.000000
# mean      12057.601763
# std        6909.750891
# min          50.010000
# 25%        6074.640000
# 50%       12062.450000
# 75%       18033.780000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
sns.displot(data=data, bins=50, x='Amount', kind='hist',hue='Class', aspect=1.5)
plt.title('Transaction Amount per Class')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
